# %%
import pandas as pd
import folium

# %% [markdown]
# ## 파일 불러오기

# %%
df1 = pd.read_csv('지진옥외대피소.csv',encoding = 'euckr')
df2 = pd.read_csv('지진해일대피소.csv',encoding = 'euckr')

# %%
df1.head()
# Out:
#          지역코드  시설일련번호   시도명 시군구명           시설명                      상세주소  \
# 0  4313000000     176  충청북도  충주시  충주교현초등학교 운동장        충청북도 충주시 교현동 339-1
# 1  4313000000     145  충청북도  충주시         대가미공원        충청북도 충주시 교현동 714-0
# 2  4313000000     146  충청북도  충주시   충주중앙중학교 운동장       충청북도 충주시 교현동 1088-0
# 3  4311000000       6  충청북도  청주시    석성초등학교 운동장  충청북도 청주시 청원구 북이면 내둔리 344
# 4  4313000000     138  충청북도  충주시       충주 관아공원        충청북도 충주시 성내동 232-2
#
#     시설면적                  경도                 위도
# 0   8500          127.936678          36.974072
# 1  32400          127.925197          36.980898
# 2   4250          127.930701          36.981533
# 3   7825  127.51374087453421  36.74848427755441
# 4   3890          127.936202          36.970501

# %%
df2.head()
# Out:
#    일련번호   시도명 시군구명  대피지구명        대피장소명                       주소          경도  \
# 0   608  경상북도  울진군  삼율지구3  7번국도 옆 공장부지    경상북도 울진군 후포면 금음리 28-4  129.436605
# 1   609  경상북도  울진군  금음지구2       풍경모텔뒷산  경상북도 울진군 후포면 금음리 산155-1  129.429702
# 2   610  경상북도  울진군  금음지구2         반소골길    경상북도 울진군 후포면 금음리 산259  129.398723
# 3   614  경상북도  울진군  삼율지구2      삼영아파트옥상  경상북도 울진군 후포면 울진대게로 24-7  129.442473
# 4   615  경상북도  울진군  삼율지구3      공영하이츠옥상   경상북도 울진군 후포면 정실2길 24-1  129.439106
#
#           위도  수용가능인원수  해변으로부터거리 대피소 분류명 내진적용여부  해발높이
# 0  36.673303      500       200      공터    NaN    30
# 1  36.664220      500       250      공터    NaN    24
# 2  36.665528      300       100      공터    NaN    20
# 3  36.677247      400       150   민간건축물    NaN    20
# 4  36.677606      500       300   민간건축물    NaN    35

# %% [markdown]
# ## 지진옥외대피소 처리
#
# - 수용가능인원수 추가
# 수용가능인원의 기준은 (군중밀집의 임계점은 m^2당 5명 so. 3명으로 잡고 반올림)
# //   참고자료 (# https://edition.cnn.com/interactive/2021/11/us/crowd-density-dangerous-warning-signs/ or https://www.donga.com/news/Society/article/all/20221031/116246753/2)
#
#
# - 위도 경도 이상한 값 처리

# %%
df1['수용가능인원수'] = round(df1['시설면적']/3).astype(int)

# %%
df1.loc[df1['위도']=='35.15.02','위도'] = '35.1502'
df1.loc[df1['경도'] =='128.37.08','경도'] = '128.3708'
df1.loc[df1['위도']=='35.15.14','위도'] = '35.1514'
df1.loc[df1['경도']=='128.36.28','경도'] = '128.3628'
df1.loc[df1['경도']=='35.481726, 126.481198','경도'] = '126.481198'

# %% [markdown]
# ## 지진옥외 / 지진해일 대피소 겹치는값 찾기
#
# - 찾다보니 지진옥외 안에서 겹치는 값과 지진해일 에서 겹치는 값도 따로 있는 것을 발견함.
#
# - 같은 데이터 안에서 겹치는 값을 지도를 통해 확인한 결과 -> 위치만 동일하고 (야산1,야산2) / (초등학교 , 중학교) 처럼 서로 다른 곳임을 발견했다.
#
# -->> 이렇게 될 경우 상세주소의 unique값이 모두 달라야 하는데 겹치는 4곳의 장소를 발견하여 확인 해 본 결과 : 같은 곳임을 확인 하였고 이 4곳만 drop 처리.
#
#
# - 우리가 찾는 것은 완전 겹치는 대피소를 찾고 있으므로 duplicated 할 때 같은 데이터 안에서 겹치는 값들은 제외하고 처리하기로 함.

# %%
df1[df1['상세주소'].duplicated(keep=False)]
# Out:
#              지역코드  시설일련번호    시도명 시군구명                     시설명  \
# 83     4315000000       3   충청북도  제천시              금성초등학교 운동장
# 84     4315000000      49   충청북도  제천시              금성초등학교 운동장
# 324    4374500000       7   충청북도  증평군               형석중학교 운동장
# 325    4374500000       9   충청북도  증평군              형석고등학교 운동장
# 439    1159000000      19  서울특별시  동작구             영등포고등학교 운동장
# ...           ...     ...    ...  ...                     ...
# 10400  1129000000      35  서울특별시  성북구               길음중학교 운동장
# 10404  1129000000      56  서울특별시  성북구   서울대학교 사범대학 부설 중학교 운동장
# 10405  1129000000      57  서울특별시  성북구  서울대학교 사범대학 부설 고등학교 운동장
# 10668  4719000000     137   경상북도  구미시              오상고등학교 운동장
# 10669  4719000000      16   경상북도  구미시               오상중학교 운동장
#
#                          상세주소   시설면적                  경도                  위도  \
# 83     충청북도 제천시 금성면 구룡리 294-0   5953  128.16544612145643   37.06719875510558
# 84     충청북도 제천시 금성면 구룡리 294-0   5953  128.16548565149745   37.06723442591937
# 324      충청북도 증평군 증평읍 미암리 603   7753  127.59314496391403   36.79279093756006
# 325      충청북도 증평군 증평읍 미암리 603   8400  127.59314496391403   36.79279093756006
# 439        서울특별시 동작구 대방동 13-2   5241  126.93383427187928  37.507988916849975
# ...                       ...    ...                 ...                 ...
# 10400     서울특별시 성북구 길음동 635-7   2062  127.01838463022357   37.61363429459085
# 10404      서울특별시 성북구 종암동 7-10  18452  127.03896757562556    37.5958036172146
# 10405      서울특별시 성북구 종암동 7-10  12736  127.03781065509901  37.592726843326155
# 10668    경상북도 구미시 장천면 상장리 700   8500  128.49672620498637   36.12386556888312
# 10669    경상북도 구미시 장천면 상장리 700   5636  128.49672620498637   36.12386556888312
#
#        수용가능인원수
# 83        1984
# 84        1984
# 324       2584
# 325       2800
# 439       1747
# ...        ...
# 10400      687
# 10404     6151
# 10405     4245
# 10668     2833
# 10669     1879
#
# [219 rows x 10 columns]

# %%
## 지진옥외대피소 겹치는 값 다른 곳인지 확인
# 4곳이 같은 것을 볼 수 있다.
df1[df1['상세주소'].duplicated(keep=False)]['시설명'].value_counts()
# Out:
# 금성초등학교 운동장      2
# 빛가온중학교 운동장      2
# 자경2어린이공원        2
# 경기항공고등학교 운동장    2
# 미성어린이공원         1
#                ..
# 서울예술고등학교 운동장    1
# 후창공원            1
# 광희중학교 운동장       1
# 무학중학교 운동장       1
# 오상중학교 운동장       1
# Name: 시설명, Length: 215, dtype: int64

# %%
lis_duplicate = ['빛가온중학교 운동장','자경2어린이공원','경기항공고등학교 운동장']

# %%
map = folium.Map(location=[36, 127], zoom_start=7)
for s in lis_duplicate:
    lat1 = df1[df1['시설명'] == s]['경도'].values[0]
    lon1 =df1[df1['시설명'] == s]['위도'].values[0]
    lat2 = df1[df1['시설명'] == s]['경도'].values[1]
    lon2 =df1[df1['시설명'] == s]['위도'].values[1]
    marker = folium.Marker([lon1,lat1],popup='1').add_to(map)
    marker = folium.Marker([lon2,lat2],popup='2').add_to(map)

## 금성초등학교는 다른지역도 있어서 따로 처리.
marker = folium.Marker([37.06719875510558,128.16544612145643],popup='1').add_to(map)
marker = folium.Marker([37.06723442591937,128.16548565149745],popup='2').add_to(map)
map

#맵을 보면 같은 곳을 지칭 하는 것을 알 수 있다.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca90a01e1a908cd73b24f0e13dfbd66b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca90a01e1a908cd73b24f0e13dfbd66b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca90a01e1a908cd73b24f0e13dfbd66b = L.map(
#                 &quot;map_ca90a01e1a908cd73b24f0e13dfbd66b&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fbad51b033ad61577687aabf7f2fb44b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ca90a01e1a908cd73b24f0e13dfbd66b);
#
#
#             var marker_40a343024d3d0ee233c3631ebc94ef6e = L.marker(
#                 [37.41177297705759, 126.88401001551041],
#                 {}
#             ).addTo(map_ca90a01e1a908cd73b24f0e13dfbd66b);
#
#
#         var popup_479f62dc4441ef5a743e92b3d176ef9e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a5964bcfd98e914dec66e2b41fcab24 = $(`&lt;div id=&quot;html_2a5964bcfd98e914dec66e2b41fcab24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_479f62dc4441ef5a743e92b3d176ef9e.setContent(html_2a5964bcfd98e914dec66e2b41fcab24);
#
#
#
#         marker_40a343024d3d0ee233c3631ebc94ef6e.bindPopup(popup_479f62dc4441ef5a743e92b3d176ef9e)
#         ;
#
#
#
#
#             var marker_d92c431beebbc50cf6168cf2ccf35de4 = L.marker(
#                 [37.4122, 126.8839],
#                 {}
#             ).addTo(map_ca90a01e1a908cd73b24f0e13dfbd66b);
#
#
#         var popup_f5b95118acb83614c6ed826563154ba0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b10c6636e56cdb9b12ed449d13c48927 = $(`&lt;div id=&quot;html_b10c6636e56cdb9b12ed449d13c48927&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_f5b95118acb83614c6ed826563154ba0.setContent(html_b10c6636e56cdb9b12ed449d13c48927);
#
#
#
#         marker_d92c431beebbc50cf6168cf2ccf35de4.bindPopup(popup_f5b95118acb83614c6ed826563154ba0)
#         ;
#
#
#
#
#             var marker_bd93b6347abaf2c5a5800e742161eadb = L.marker(
#                 [37.42119394309046, 126.89128925894575],
#                 {}
#             ).addTo(map_ca90a01e1a908cd73b24f0e13dfbd66b);
#
#
#         var popup_f4b9b53c8b42815c68bf1f17c32044b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_940a7ffa6575d3b25d2da2982cc251a4 = $(`&lt;div id=&quot;html_940a7ffa6575d3b25d2da2982cc251a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_f4b9b53c8b42815c68bf1f17c32044b6.setContent(html_940a7ffa6575d3b25d2da2982cc251a4);
#
#
#
#         marker_bd93b6347abaf2c5a5800e742161eadb.bindPopup(popup_f4b9b53c8b42815c68bf1f17c32044b6)
#         ;
#
#
#
#
#             var marker_233d514a7b21b6feb5b6f3bd1848ffcc = L.marker(
#                 [37.421602, 126.891165],
#                 {}
#             ).addTo(map_ca90a01e1a908cd73b24f0e13dfbd66b);
#
#
#         var popup_89cecf7fa25b2bb0ecc3205e4221f46b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f7a4464f37ebe818d2d9bf6c110bedc = $(`&lt;div id=&quot;html_0f7a4464f37ebe818d2d9bf6c110bedc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_89cecf7fa25b2bb0ecc3205e4221f46b.setContent(html_0f7a4464f37ebe818d2d9bf6c110bedc);
#
#
#
#         marker_233d514a7b21b6feb5b6f3bd1848ffcc.bindPopup(popup_89cecf7fa25b2bb0ecc3205e4221f46b)
#         ;
#
#
#
#
#             var marker_9573d8491ab017ee2118f4e319f84c12 = L.marker(
#                 [37.47367244935281, 126.85766454785754],
#                 {}
#             ).addTo(map_ca90a01e1a908cd73b24f0e13dfbd66b);
#
#
#         var popup_b205f19ed7368f3c6bb3b46ad6a8edcc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d0b671b720670b0cff356c75f614f87a = $(`&lt;div id=&quot;html_d0b671b720670b0cff356c75f614f87a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_b205f19ed7368f3c6bb3b46ad6a8edcc.setContent(html_d0b671b720670b0cff356c75f614f87a);
#
#
#
#         marker_9573d8491ab017ee2118f4e319f84c12.bindPopup(popup_b205f19ed7368f3c6bb3b46ad6a8edcc)
#         ;
#
#
#
#
#             var marker_f978b1d26aad2973cc49c719ca35394b = L.marker(
#                 [37.4732, 126.8572],
#                 {}
#             ).addTo(map_ca90a01e1a908cd73b24f0e13dfbd66b);
#
#
#         var popup_22acd719fe163f387a1a7d36c67006eb = L.popup({&quot;ma

# %%
# 지진옥외대피소에서 겹치는 4곳 지우기.
df1 = df1.drop(index = df1[df1['시설명'] == '금성초등학교 운동장'][:1].index)
for g in lis_duplicate:
    df1 = df1.drop(index = df1[df1['시설명'] == g][:1].index)
df1.reset_index(inplace =  True)

# %%
## 지진해일대피소 겹치는 값 다른 곳인지 확인
df2[df2['주소'].duplicated(keep = False)]
df = df2[df2['주소'] == '강원도 양양군 현남면 남애리 1']
# Out:
#      일련번호   시도명 시군구명  대피지구명     대피장소명                   주소          경도  \
# 14    622  경상북도  울진군  후포지구1   마을뒷산고지대  경상북도 울진군 후포면 후포리 37  129.464291
# 15    623  경상북도  울진군  후포지구1  마을뒷산 고지대  경상북도 울진군 후포면 후포리 37  129.464335
# 283   268   강원도  양양군   남애지구  남애리 야산 1    강원도 양양군 현남면 남애리 1  128.786052
# 284   269   강원도  양양군   남애지구  남애리 야산 2    강원도 양양군 현남면 남애리 1  128.785876
# 285   270   강원도  양양군   남애지구  남애리 야산 3    강원도 양양군 현남면 남애리 1  128.786258
#
#             위도  수용가능인원수  해변으로부터거리 대피소 분류명 내진적용여부  해발높이
# 14   36.688566      200       120      공터    NaN    20
# 15   36.688388      200       100      공터    NaN    19
# 283  37.945723      200       300      공터    NaN    30
# 284  37.941682      200       200      공터    NaN    25
# 285  37.945462      200       300      공터    NaN    25

# %%
import folium
map = folium.Map(location=[36, 127], zoom_start=7)
for i in df.index:
    lat = df.loc[i, '위도']
    lon = df.loc[i, '경도']
    marker = folium.Marker([lat,lon]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb7e8fb45a9bd3be5be2488d5f444802 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb7e8fb45a9bd3be5be2488d5f444802&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb7e8fb45a9bd3be5be2488d5f444802 = L.map(
#                 &quot;map_bb7e8fb45a9bd3be5be2488d5f444802&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40bbfeb708e9d52c806ab2653c614524 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb7e8fb45a9bd3be5be2488d5f444802);
#
#
#             var marker_fc9a0d414292b59fa4f4a95cf378f435 = L.marker(
#                 [37.945723, 128.786052],
#                 {}
#             ).addTo(map_bb7e8fb45a9bd3be5be2488d5f444802);
#
#
#             var marker_f1915d3f83d9f427149c06aca7a8b471 = L.marker(
#                 [37.941682, 128.785876],
#                 {}
#             ).addTo(map_bb7e8fb45a9bd3be5be2488d5f444802);
#
#
#             var marker_e5bb311283197d62124404f59b2c96ff = L.marker(
#                 [37.945462, 128.786258],
#                 {}
#             ).addTo(map_bb7e8fb45a9bd3be5be2488d5f444802);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#지진해일 / 지진옥외 주소 합치기
df1_test = df1[['상세주소']]
df2_test = df2[['주소']]
df2_test = df2_test.rename({'주소':'상세주소'},axis =1)
df_address = pd.concat([df1_test,df2_test],axis = 0,ignore_index=True)

# df1_test 이랑 df2_test 겹치면 df2_test 결과 가져오려고 keep='first'
df_address_tot = df_address[df_address.duplicated(keep = 'first')]
# Out:
# C:\Users\goyangi\AppData\Local\Temp\ipykernel_38056\222395038.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_test.rename({'주소':'상세주소'},axis =1, inplace=True)

# %%
df2[df2['주소'].duplicated()]
# Out:
#      일련번호   시도명 시군구명  대피지구명     대피장소명                   주소          경도  \
# 15    623  경상북도  울진군  후포지구1  마을뒷산 고지대  경상북도 울진군 후포면 후포리 37  129.464335
# 284   269   강원도  양양군   남애지구  남애리 야산 2    강원도 양양군 현남면 남애리 1  128.785876
# 285   270   강원도  양양군   남애지구  남애리 야산 3    강원도 양양군 현남면 남애리 1  128.786258
#
#             위도  수용가능인원수  해변으로부터거리 대피소 분류명 내진적용여부  해발높이
# 15   36.688388      200       100      공터    NaN    19
# 284  37.941682      200       200      공터    NaN    25
# 285  37.945462      200       300      공터    NaN    25

# %%
# df1 / df2 각각의 겹치는 값들은 그대로 
df_address_tot = df_address_tot.drop(index = [10887,11156,11157])

# %%
## 지진옥외 / 지진해일 대피소 겹치는값.
## 10872는 df1의 row값
duplicated_list = df_address_tot[df_address_tot.index > 10872].index

# %%
duplicated_list
# Out:
# Int64Index([10918, 10919, 10924, 10951, 10955, 10965, 10967, 10968, 10989,
#             10995, 11017, 11019, 11021, 11025, 11042, 11119, 11148, 11150,
#             11208, 11230, 11234, 11263, 11271, 11280, 11283, 11291, 11293,
#             11318, 11401, 11437],
#            dtype='int64')

# %%
len(duplicated_list)
# Out:
# 30

# %% [markdown]
# ## 지진해일 / 지진옥외 대피소 합치기
#
# - (겹치는 값을 df2기준으로 찾았기 때문에) df2가 밑에 있게 합쳐야 한다.
# - 따라서 df2를 df1과 동일한 column명 / 동일한 column 개수가 되어야 한다.
#
# - 또한 합친 후 인구 변화도 함께 볼 것이기 때문에 지진옥외 대피소와 지진해일 대피소의 '시군구명'이 겹치는 부분을 확인 한 결과 포항시 남구의 변화만 주면 이상없다.

# %%
df1.shape , df2.shape
# Out:
# ((10872, 11), (648, 13))

# %%
df2.loc[df2['시군구명'] == '포항시남구','시군구명'] = '포항시 남구'

# %%
df2.rename({'대피장소명':'시설명','주소':'상세주소'}, axis=1,inplace = True)

# %%
df1 = df1[['시도명','시군구명','시설명','상세주소','경도','위도','수용가능인원수']]
df2 = df2[['시도명','시군구명','시설명','상세주소','경도','위도','수용가능인원수']]
df_total = pd.concat([df1,df2],axis = 0 , ignore_index= True)

# %% [markdown]
# ## 지진해일 / 지진옥외 대피소 동일 주소 처리
#
# - 값을 처리하다 보니 지진옥외대피소의 수용가능인원을 위에서 임의의 기준을 잡았는데 동일한 주소이면 수용가능인원이 동일해야 된다는 생각이 들었다.
# - 확인 결과 값이 차이가 나서 지도화를 하여 비교해 본 결과
# - 지진옥외대피소를 기준으로 보는 것이 더 정확한 것 같았다.
# - 그래서 중복값을 지울 때 지진해일 데이터를 지웠다

# %%
## 지진옥외대피소랑 지진해일대피소 동일주소의 수용가능인원 확인

# %%
total_duplicate = df_total[df_total['상세주소'].duplicated(keep = False)]

# %%
total_duplicate
# Out:
#          시도명 시군구명          시설명                    상세주소                  경도  \
# 323     충청북도  증평군    형석중학교 운동장    충청북도 증평군 증평읍 미암리 603  127.59314496391403
# 324     충청북도  증평군   형석고등학교 운동장    충청북도 증평군 증평읍 미암리 603  127.59314496391403
# 438    서울특별시  동작구  영등포고등학교 운동장      서울특별시 동작구 대방동 13-2  126.93383427187928
# 440    서울특별시  동작구   영등포중학교 운동장      서울특별시 동작구 대방동 13-2  126.93286097282864
# 501     전라북도  김제시     덕암정보고등학교        전라북도 김제시 서암동 5-0  126.88681629845776
# ...      ...  ...          ...                     ...                 ...
# 11291   경상북도  경주시    양남중학교 운동장    경상북도 경주시 양남면 하서리 651          129.460154
# 11293   경상북도  경주시       나산초등학교     경상북도 경주시 양남면 읍천리 17            129.4703
# 11318   경상북도  경주시     감포중·고등학교  경상북도 경주시 감포읍 오류리 478-2          129.506759
# 11401   경상북도  울진군       사동초등학교    경상북도 울진군 기성면 사동리 455          129.437804
# 11437   경상북도  울진군      부구초등학교옆     경상북도 울진군 북면 부구리 278          129.372029
#
#                        위도  수용가능인원수
# 323     36.79279093756006     2584
# 324     36.79279093756006     2800
# 438    37.507988916849975     1747
# 440     37.50812488139663     1120
# 501      35.8132608257477     1546
# ...                   ...      ...
# 11291           35.673865     1000
# 11293            35.69788     1000
# 11318           35.810771     1300
# 11401           36.830099      500
# 11437           37.102301      100
#
# [276 rows x 7 columns]

# %%
df1_duplicate = df1[df1['상세주소'].duplicated()].index
df2_duplicate = df2[df2['상세주소'].duplicated()].index

# %%
total_duplicate = total_duplicate.drop(index = list(df1_duplicate))
df2_duplicate = df2_duplicate+10872
duplicate_test = total_duplicate.drop(index = list(df2_duplicate))

# %%
# 1(600개 데이터) 이 지진해일대피소  2가 지진옥외대피소 ->
# 2를 임의로 설정 하였으니 틀린지 보면 된다.
duplicate_test_1 = duplicate_test[duplicate_test['상세주소'].duplicated(keep='first')]
duplicate_test_2 = duplicate_test[duplicate_test['상세주소'].duplicated(keep='last')]
duplicate_test_total = pd.merge(duplicate_test_1[['상세주소','수용가능인원수']],duplicate_test_2[['상세주소','수용가능인원수']], on='상세주소')

# %%
# 값을 보니 다른 부분이 많은 듯.
duplicate_test_total.head()
# Out:
#                      상세주소  수용가능인원수_x  수용가능인원수_y
# 0    경상북도 울릉군 서면 남서리 30-3        400        632
# 1  경상북도 울릉군 울릉읍 도동리 223-8        400       1100
# 2   경상북도 울릉군 서면 남양리 586-2        400        989
# 3        울산광역시 동구 주전동 277       3939        595
# 4        울산광역시 동구 일산동 963       5212       2033

# %%
map = folium.Map(location=[36, 127], zoom_start=7)
for add in duplicate_test_total['상세주소']:
    lat1 = df1[df1['상세주소'] == add]['경도'].values[0]
    lon1 =df1[df1['상세주소'] == add]['위도'].values[0]
    lat2 = df2[df2['상세주소'] == add]['경도'].values[0]
    lon2 = df2[df2['상세주소'] == add]['위도'].values[0]
    marker = folium.Marker([lon1,lat1],popup='1지진옥외').add_to(map)
    marker = folium.Marker([lon2,lat2],popup='2지진해일').add_to(map)
map
#google map / naver map(면적 계산) 을 이용해 보았을 때 시설면적(지진옥외)가 더 정확한 것 같다. ex) 포항에 있는 환호공원)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a1f1e937032ec89879c2933d691bfe2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a1f1e937032ec89879c2933d691bfe2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a1f1e937032ec89879c2933d691bfe2 = L.map(
#                 &quot;map_2a1f1e937032ec89879c2933d691bfe2&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94a4c7007dd0c45aaf4b727a5a507f97 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2a1f1e937032ec89879c2933d691bfe2);
#
#
#             var marker_c826f8f7de8fc84e35c201407aaec500 = L.marker(
#                 [37.47400144350776, 130.834079752831],
#                 {}
#             ).addTo(map_2a1f1e937032ec89879c2933d691bfe2);
#
#
#         var popup_2785cc603098040f01856be8435ef5cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4107f5660a8765161217dc6f719616e = $(`&lt;div id=&quot;html_d4107f5660a8765161217dc6f719616e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1지진옥외&lt;/div&gt;`)[0];
#                 popup_2785cc603098040f01856be8435ef5cb.setContent(html_d4107f5660a8765161217dc6f719616e);
#
#
#
#         marker_c826f8f7de8fc84e35c201407aaec500.bindPopup(popup_2785cc603098040f01856be8435ef5cb)
#         ;
#
#
#
#
#             var marker_1bd8348f28dfa28ef4448c6c15e8d45c = L.marker(
#                 [37.468891, 130.836369],
#                 {}
#             ).addTo(map_2a1f1e937032ec89879c2933d691bfe2);
#
#
#         var popup_0cdfaae24eaedd83a9438efc5a5ff6fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6f7c8b936acb7bdc9c922faea76dce4 = $(`&lt;div id=&quot;html_e6f7c8b936acb7bdc9c922faea76dce4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2지진해일&lt;/div&gt;`)[0];
#                 popup_0cdfaae24eaedd83a9438efc5a5ff6fd.setContent(html_e6f7c8b936acb7bdc9c922faea76dce4);
#
#
#
#         marker_1bd8348f28dfa28ef4448c6c15e8d45c.bindPopup(popup_0cdfaae24eaedd83a9438efc5a5ff6fd)
#         ;
#
#
#
#
#             var marker_28b996e01f5ef82c85b7bd9871dbafde = L.marker(
#                 [37.488321807419986, 130.90072908834665],
#                 {}
#             ).addTo(map_2a1f1e937032ec89879c2933d691bfe2);
#
#
#         var popup_c474fc0e1f18b8c40b5f44d664fae19a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_808b0eef80506d997eff2d38d9a6bb56 = $(`&lt;div id=&quot;html_808b0eef80506d997eff2d38d9a6bb56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1지진옥외&lt;/div&gt;`)[0];
#                 popup_c474fc0e1f18b8c40b5f44d664fae19a.setContent(html_808b0eef80506d997eff2d38d9a6bb56);
#
#
#
#         marker_28b996e01f5ef82c85b7bd9871dbafde.bindPopup(popup_c474fc0e1f18b8c40b5f44d664fae19a)
#         ;
#
#
#
#
#             var marker_8382e20b19a7267bbd1d971824c88876 = L.marker(
#                 [37.484955, 130.902622],
#                 {}
#             ).addTo(map_2a1f1e937032ec89879c2933d691bfe2);
#
#
#         var popup_0e8c64d466a93ff6375933553eaa8fff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50530bf170a71bd51474dd39002b0973 = $(`&lt;div id=&quot;html_50530bf170a71bd51474dd39002b0973&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2지진해일&lt;/div&gt;`)[0];
#                 popup_0e8c64d466a93ff6375933553eaa8fff.setContent(html_50530bf170a71bd51474dd39002b0973);
#
#
#
#         marker_8382e20b19a7267bbd1d971824c88876.bindPopup(popup_0e8c64d466a93ff6375933553eaa8fff)
#         ;
#
#
#
#
#             var marker_f08947c2eb0008fdc9be8e445a73573e = L.marker(
#                 [37.4734698985828, 130.8378123848631],
#                 {}
#             ).addTo(map_2a1f1e937032ec89879c2933d691bfe2);
#
#
#         var popup_2eee62dd0597be0d6aadca3b378e5a78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ba58c982dd962cb0402be5392353282 = $(`&lt;div id=&quot;html_0ba58c982dd962cb0402be5392353282&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1지진옥외&lt;/div&gt;`)[0];
#                 popup_2eee62dd0597be0d6aadca3b378e5a78.setContent(html_0ba58c982dd962cb0402be5392353282);
#
#
#
#         marker_f08947c2eb0008fdc9be8e445a73573e.bindPopup(popup_2eee62dd0597be0d6aadca3b378e5a78)
#         ;
#
#
#
#
#             var marker_7f5239c417dbeb97fec390b227b62023 = L.marker(
#                 [37.46863, 130.8399],
#                 {}
#             ).addTo(map_2a1f1e937032ec89879c2933d691bfe2);
#
#
#         var popup_71d68520cd0be9c09a2ee8811253a8

# %%
#지진해일 데이터로 지우기.
df_total = df_total.drop(index = duplicated_list, axis = 0)
df_total.reset_index(drop='index', inplace = True)

# %% [markdown]
# ## 데이터 저장

# %%
df_total.to_csv('지진대피소 종합본.csv',encoding='euckr')

# %% [markdown]
# 앞으로 해야 할 것.
